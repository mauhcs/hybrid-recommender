# %% [markdown]
# This notebook contains a visual history of most of the models tried during the exploration phase.
#
# Since many of the plots lost their subtiles or context this notebook usefulness is limited and the main takeaway is that most of the models were at the same neighborhood when it comes to accuracy.
#
# This notebook is useful for quickly evaluate a model from another notebook without cluttering that notebook with metrics.

# %%
import warnings
warnings.filterwarnings("ignore")

# %pylab inline
# %load_ext autoreload
# %autoreload 2

import pandas as pd

from utils.evaluate import evaluate, spark_filepath_to_pandas
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
filepath = f'data/spark_asl.tsv' 
filepath = f'data/sgd_{16409}.tsv' 
filepath = "data/spark_kmeans_100.tsv"
filepath = "data/spark_asl_target_users.tsv"

nDCGs, entropy, globalVar = evaluate(filepath, spark_file=True)

metrics = pd.DataFrame(nDCGs, columns=["user_id", "nDCGs"])
print(f"nDCG avg:{metrics.nDCGs.mean():.4}")
# Out:
# 221,000 / 221,793 (99.64)%
# Stoping Writer
# Entropy: 6.272028486086872
# nDCG avg:2.925e-05

# %%
# kmeans all set

avg = metrics.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(metrics.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy:.4f}")
plt.title(f"{filepath}")
plt.xlabel("nDCG@72")
_ = plt.legend()

# %%
# kmeans all set

avg = metrics.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(metrics.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy:.4f}")
plt.title(f"{filepath}")
plt.xlabel("nDCG@72")
_ = plt.legend()

# %%
# kmeans all set

avg = metrics.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(metrics.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy:.4f}")
plt.title(f"{filepath}")
plt.xlabel("nDCG@72")
_ = plt.legend()

# %%
# kmeans small set

avg = metrics.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(metrics.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy:.4f}")
plt.title(f"{filepath}")
plt.xlabel("nDCG@72")
_ = plt.legend()

# %%
# SGD

avg = metrics.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(metrics.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy:.4f}")
plt.title(f"{filepath}")
plt.xlabel("nDCG@72")
_ = plt.legend()

# %%
# 1% of trainign data 
# maxIter=10 # rank=15

avg = metrics.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(metrics.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy:.4f}")
plt.title("ALS / All Item History Train data")
plt.xlabel("nDCG@72")
_ = plt.legend()

# %%
# 1% of trainign data 
# maxIter=15 # rank=15

avg = metrics.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(metrics.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy:.4f}")
plt.title("ALS / All Item History Train data")
plt.xlabel("nDCG@72")
_ = plt.legend()

# %%
# 1% of trainign data 
# maxIter=25 # rank=15

avg = metrics.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(metrics.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy:.4f}")
plt.title("ALS / All Item History Train data")
plt.xlabel("nDCG@72")
_ = plt.legend()

# %%
# 1% of trainign data 
# maxIter=20 # rank=20

avg = metrics.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(metrics.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy:.4f}")
plt.title("ALS / All Item History Train data")
plt.xlabel("nDCG@72")
_ = plt.legend()

# %%
# 1% of trainign data 
# maxIter=20 # rank=15

avg = metrics.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(metrics.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy:.4f}")
plt.title("ALS / All Item History Train data")
plt.xlabel("nDCG@72")
_ = plt.legend()

# %%
# 1% of trainign data
# maxIter=10 # rank=10
avg = metrics.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(metrics.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy:.4f}")
plt.title("ALS / All Item History Train data")
plt.xlabel("nDCG@72")
_ = plt.legend()

# %%
# .5% of trainign data
avg = metrics.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(metrics.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy:.4f}")
plt.title("ALS / All Item History Train data")
plt.xlabel("nDCG@72")
_ = plt.legend()

# %%
# .1% of tarining data
avg = metrics.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(metrics.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy:.4f}")
plt.title("ALS / All Item History Train data")
plt.xlabel("nDCG@72")
_ = plt.legend()

# %%
avg = metrics.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(metrics.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy:.4f}")
plt.title("ALS / All Item History Train data")
plt.xlabel("nDCG@72")
_ = plt.legend()

# %%
avg = metrics.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(metrics.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy:.4f}")
_ = plt.legend()

# %%
avg = metrics.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(metrics.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy:.4f}")
_ = plt.legend()

# %%
avg = metrics.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(metrics.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy:.4f}")
_ = plt.legend()

# %%
avg = metrics.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(metrics.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy:.4f}")
_ = plt.legend()

# %%
avg = df.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(df.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy:.4f}")
_ = plt.legend()

# %%
avg = df.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(df.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy:.4f}")
_ = plt.legend()

# %%
avg = df.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(df.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy:.4f}")
_ = plt.legend()

# %%
avg = df.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(df.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy_at_72:.4f}")
_ = plt.legend()

# %%
avg = df.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(df.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy_at_72:.4f}")
_ = plt.legend()

# %%
avg = df.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(df.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy_at_72:.4f}")
_ = plt.legend()

# %%
avg = df.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(df.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy_at_72:.4f}")
_ = plt.legend()

# %%
avg = df.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(df.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy_at_72:.4f}")
_ = plt.legend()

# %%
avg = df.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(df.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy_at_72:.4f}")
_ = plt.legend()

# %%
avg = df.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(df.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy_at_72:.4f}")
_ = plt.legend()

# %%
avg = df.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(df.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy_at_72:.4f}")
_ = plt.legend()

# %%
avg = df.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(df.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy_at_72:.4f}")
_ = plt.legend()

# %%
avg = df.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(df.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy_at_72:.4f}")
_ = plt.legend()

# %%
avg = df.nDCGs.mean()
_ = plt.figure(figsize=(12,3))
_ = plt.hist(df.nDCGs, bins=50, label=f"Avg:{avg:>21.4f}\nEntropy@72: {entropy_at_72:.4f}")
_ = plt.legend()
